# %%
import pandas as pd

# %%
credit_train = pd.read_csv("credit_train.csv", encoding="WINDOWS-1252", sep=";")

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
credit_train.head(10)
# Out:
#    client_id gender  age marital_status job_position credit_sum  credit_month  \
# 0          1      M   48            MAR          UMN   59998,00            10
# 1          2      F   28            MAR          UMN   10889,00             6
# 2          3      M   32            MAR          SPC   10728,00            12
# 3          4      F   27            DIV          SPC   12009,09            12
# 4          5      M   45            MAR          SPC   16908,89            10
# 5          6      F   37            MAR          SPC   26788,00            10
# 6          7      M   34            MAR          SPC   10317,00             6
# 7          8      F   26            UNM          SPC   47878,00            10
# 8          9      M   23            UNM          SPC   37577,16            12
# 9         10      F   32            UNM          SPC   26268,00            10
#
#    tariff_id score_shk education                             living_region  \
# 0        1.6  0,770249       GRD                        ÊÐÀÑÍÎÄÀÐÑÊÈÉ ÊÐÀÉ
# 1        1.1  0,248514       GRD                                    ÌÎÑÊÂÀ
# 2        1.1  0,459589       SCH                           ÎÁË ÑÀÐÀÒÎÂÑÊÀß
# 3        1.1  0,362536       GRD                         ÎÁË ÂÎËÃÎÃÐÀÄÑÊÀß
# 4        1.1  0,421385       SCH                       ×ÅËßÁÈÍÑÊÀß ÎÁËÀÑÒÜ
# 5        1.1  0,484203       SCH                       ÑÒÀÂÐÎÏÎËÜÑÊÈÉ ÊÐÀÉ
# 6        1.5  0,276012       SCH                         ÎÁË ÍÈÆÅÃÎÐÎÄÑÊÀß
# 7        1.1  0,512525       GRD                            ÌÎÑÊÎÂÑÊÀß ÎÁË
# 8        1.6  0,642267       SCH  ÕÀÍÒÛ-ÌÀÍÑÈÉÑÊÈÉ ÀÂÒÎÍÎÌÍÛÉ ÎÊÐÓÃ - ÞÃÐÀ
# 9        1.1  0,465026       GRD                       ÊÐÀÉ ÑÒÀÂÐÎÏÎËÜÑÊÈÉ
#
#    monthly_income  credit_count  overdue_credit_count  open_account_flg
# 0         30000.0           1.0                   1.0                 0
# 1         43000.0           2.0                   0.0                 0
# 2         23000.0           5.0                   0.0                 0
# 3         17000.0           2.0                   0.0                 0
# 4         25000.0           1.0                   0.0                 0
# 5         30000.0           0.0                   0.0                 0
# 6         28000.0           3.0                   0.0                 0
# 7         60000.0           3.0                   0.0                 0
# 8         50000.0           3.0                   0.0                 0
# 9         39500.0           7.0                   0.0                 0

# %%
target_by_region = credit_train.groupby("living_region").agg({'client_id': 'count', 'open_account_flg': 'mean'}).reset_index()

# %%
target_by_region[target_by_region.client_id > 50].sort_values("open_account_flg").plot.bar(x='living_region', y='open_account_flg', rot=90)
# Out:
# <AxesSubplot:xlabel='living_region'>

# %%
target_by_edu = credit_train.groupby("education").agg({'client_id': 'count', 'open_account_flg': 'mean'}).reset_index()

# %%
target_by_edu.sort_values("open_account_flg").plot.bar(x='education', y='open_account_flg', rot=90)
# Out:
# <AxesSubplot:xlabel='education'>

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

x = credit_train[(credit_train.open_account_flg == 1) & (credit_train.monthly_income <= 200000)].score_shk.apply(lambda x: x.replace(",",".")).astype("float")
y = credit_train[(credit_train.open_account_flg == 0) & (credit_train.monthly_income <= 200000)].score_shk.apply(lambda x: x.replace(",",".")).astype("float")
#bins = np.linspace(-10, 10, 30)

plt.hist([x, y],  label=['1', '0'], bins=20, density=True)
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

x = credit_train[(credit_train.open_account_flg == 1)].credit_count
y = credit_train[(credit_train.open_account_flg == 0)].credit_count
#bins = np.linspace(-10, 10, 30)

plt.hist([x, y],  label=['1', '0'], bins=20, density=True)
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

x = credit_train[(credit_train.open_account_flg == 1)].credit_sum.apply(lambda x: x.replace(",",".")).astype("float")
y = credit_train[(credit_train.open_account_flg == 0)].credit_sum.apply(lambda x: x.replace(",",".")).astype("float")
#bins = np.linspace(-10, 10, 30)

plt.hist([x, y],  label=['1', '0'], bins=20, density=True)
plt.legend(loc='upper right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

x = credit_train[(credit_train.open_account_flg == 1)].age
y = credit_train[(credit_train.open_account_flg == 0)].age
#bins = np.linspace(-10, 10, 30)

plt.hist([x, y],  label=['1', '0'], bins=20, density=True)
plt.legend(loc='upper right')
plt.show()
